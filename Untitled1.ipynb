# %% [markdown]
# <a href="https://colab.research.google.com/github/viratk8861-cyber/aaaaa/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/student_placement/
# Out:
# /content/drive/MyDrive/student_placement

# %%
ls -l
# Out:
# total 34
# -rw------- 1 root root 34442 Jun 30 05:28 placement_extended_1000.csv

# %%
import pandas as pd


df = pd.read_csv('/content/drive/MyDrive/student_placement/placement_extended_1000.csv')

df.head()
# Out:
#    Attendance  CGPA  Communication Internship  Projects  Programming  \
# 0         100  7.01              4         No         5           83
# 1          93  8.69             10         No         4           40
# 2          75  7.52              3         No         4           45
# 3          75  7.52              3        Yes         5           81
# 4          56  9.11              9        Yes         5           73
#
#    PerformanceIndex  HasInternship Placement
# 0            132.98              0    Placed
# 1            146.12              0    Placed
# 2            113.66              0    Placed
# 3            138.46              1    Placed
# 4            162.98              1    Placed
